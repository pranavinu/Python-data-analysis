# %% [markdown]
# ### Project Summary:
# 1.	Problem Statement:
#      a.	To build a trained model which can predict the employee performance based on factors as inputs.
#      b.	To Provide Recommendations to improve the employee performance based on insights from analysis.
#
# 2.	Training Model:
#      a.	It is a classification problem.
#      b.	Implemented XGBOOST Machine learning algorithm because of the inconsistency in the data.
#      c.	Dropped the Employee Number column from the feature variables because there is no relation between the Employee number         and performance Rating.
#
# 3.	Tools and Technologies:
#     a.	Python 3 - Programming language.
#     b.	Jupyter notebook –  Web application which allows to create and Share documents that contain live code.
#     c.	Machine learning.

# %% [markdown]
# ### Importing the Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier, MLPRegressor

# %% [markdown]
# ### Reading the data from the source file provided

# %%
data = pd.read_csv("INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv")

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Observing the first five rows of the data

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %% [markdown]
# #### Information of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %% [markdown]
# #### Column names of the data frame

# %%
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %% [markdown]
# #### Finding the count of the values in the Performance Rating column
#  -> Data is inconsistent

# %%
from collections import Counter
Counter(data.PerformanceRating)
# Out:
# Counter({3: 874, 4: 132, 2: 194})

# %% [markdown]
# #### Plotting the data to find any outliers
# 1. Data is in normal distribution and free from outliers.

# %%
# %matplotlib inline

# %%
data.hist(bins=50, figsize=(20,15))
data.plot()
